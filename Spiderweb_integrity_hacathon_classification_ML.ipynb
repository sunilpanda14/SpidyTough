# %%
# !pip install pandas numpy scikit-learn autogluon

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from autogluon.tabular import TabularPredictor
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/sunil/.local/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: numpy in /home/sunil/.local/lib/python3.10/site-packages (1.26.4)
# Requirement already satisfied: scikit-learn in /home/sunil/.local/lib/python3.10/site-packages (1.4.0)
# Requirement already satisfied: autogluon in /home/sunil/.local/lib/python3.10/site-packages (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/sunil/.local/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/sunil/.local/lib/python3.10/site-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /home/sunil/.local/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: scipy>=1.6.0 in /home/sunil/.local/lib/python3.10/site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/sunil/.local/lib/python3.10/site-packages (from scikit-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/sunil/.local/lib/python3.10/site-packages (from scikit-learn) (3.4.0)
# Requirement already satisfied: autogluon.core==1.1.0 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.core[all]==1.1.0->autogluon) (1.1.0)
# Requirement already satisfied: autogluon.features==1.1.0 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon) (1.1.0)
# Requirement already satisfied: autogluon.tabular==1.1.0 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.tabular[all]==1.1.0->autogluon) (1.1.0)
# Requirement already satisfied: autogluon.multimodal==1.1.0 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon) (1.1.0)
# Requirement already satisfied: autogluon.timeseries==1.1.0 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.timeseries[all]==1.1.0->autogluon) (1.1.0)
# Requirement already satisfied: networkx<4,>=3.0 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (3.3)
# Requirement already satisfied: tqdm<5,>=4.38 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (4.65.2)
# Requirement already satisfied: requests in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (2.28.2)
# Requirement already satisfied: matplotlib in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (3.8.4)
# Requirement already satisfied: boto3<2,>=1.10 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (1.34.113)
# Requirement already satisfied: autogluon.common==1.1.0 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (1.1.0)
# Requirement already satisfied: ray<2.11,>=2.10.0 in /home/sunil/.local/lib/python3.10/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (2.10.0)
# Requirement already satisfied: hyperopt<0.2.8,>=0.2.7 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.core[all]==1.1.0->autogluon) (0.2.7)
# Requirement already satisfied: Pillow<11,>=10.0.1 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon) (10.3.0)
# Requirement already satisfied: torch<2.2,>=2.1 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon) (2.1.2)
# Requirement already satisfied: lightning<2.2,>=2.1 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon) (2.1.4)
# Requirement already satisfied: transformers<4.39.0,>=4.38.0 in /home/sunil/.local/lib/python3.10/site-packages (from transformers[sentencepiece]<4.39.0,>=4.38.0->autogluon.multimodal==1.1.0->autogluon) (4.38.2)
# Requirement already satisfied: accelerate<0.22.0,>=0.21.0 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.21.0)
# Requirement already satisfied: jsonschema<4.22,>=4.18 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon) (4.21.1)
# Requirement already satisfied: seqeval<1.3.0,>=1.2.2 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon) (1.2.2)
# Requirement already satisfied: evaluate<0.5.0,>=0.4.0 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.4.2)
# Requirement already satisfied: timm<0.10.0,>=0.9.5 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.9.16)
# Requirement already satisfied: torchvision<0.17.0,>=0.16.0 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.16.2)
# Requirement already satisfied: scikit-image<0.21.0,>=0.19.1 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.20.0)
# Requirement already satisfied: text-unidecode<1.4,>=1.3 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon) (1.3)
# Requirement already satisfied: torchmetrics<1.3.0,>=1.2.0 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon) (1.2.1)
# Requirement already satisfied: nptyping<2.5.0,>=1.4.4 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon) (2.4.1)
# Requirement already satisfied: omegaconf<2.3.0,>=2.1.1 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon) (2.2.3)
# Requirement already satisfied: pytorch-metric-learning<2.4,>=1.3.0 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon) (2.3.0)
# Requirement already satisfied: nlpaug<1.2.0,>=1.1.10 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon) (1.1.11)
# Requirement already satisfied: nltk<4.0.0,>=3.4.5 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon) (3.8.1)
# Requirement already satisfied: openmim<0.4.0,>=0.3.7 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.3.9)
# Requirement already satisfied: defusedxml<0.7.2,>=0.7.1 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.7.1)
# Requirement already satisfied: jinja2<3.2,>=3.0.3 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon) (3.1.3)
# Requirement already satisfied: tensorboard<3,>=2.9 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon) (2.16.2)
# Requirement already satisfied: pytesseract<0.3.11,>=0.3.9 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.3.10)
# Requirement already satisfied: nvidia-ml-py3==7.352.0 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon) (7.352.0)
# Requirement already satisfied: pdf2image<1.19,>=1.17.0 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.multimodal==1.1.0->autogluon) (1.17.0)
# Requirement already satisfied: xgboost<2.1,>=1.6 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.tabular[all]==1.1.0->autogluon) (2.0.3)
# Requirement already satisfied: fastai<2.8,>=2.3.1 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.tabular[all]==1.1.0->autogluon) (2.7.15)
# Requirement already satisfied: lightgbm<4.4,>=3.3 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.tabular[all]==1.1.0->autogluon) (4.3.0)
# Requirement already satisfied: catboost<1.3,>=1.1 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.tabular[all]==1.1.0->autogluon) (1.2.5)
# Requirement already satisfied: pytorch-lightning<2.2,>=2.1 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (2.1.4)
# Requirement already satisfied: gluonts<0.14.4,>=0.14.0 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.14.3)
# Requirement already satisfied: statsforecast<1.5,>=1.4.0 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (1.4.0)
# Requirement already satisfied: mlforecast<0.10.1,>=0.10.0 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.10.0)
# Requirement already satisfied: utilsforecast<0.0.11,>=0.0.10 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.0.10)
# Requirement already satisfied: orjson~=3.9 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (3.10.3)
# Requirement already satisfied: optimum<1.19,>=1.17 in /home/sunil/.local/lib/python3.10/site-packages (from optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon) (1.18.1)
# Requirement already satisfied: psutil<6,>=5.7.3 in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.common==1.1.0->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (5.9.8)
# Requirement already satisfied: setuptools in /home/sunil/.local/lib/python3.10/site-packages (from autogluon.common==1.1.0->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (60.2.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: packaging>=20.0 in /home/sunil/.local/lib/python3.10/site-packages (from accelerate<0.22.0,>=0.21.0->autogluon.multimodal==1.1.0->autogluon) (24.0)
# Requirement already satisfied: pyyaml in /home/sunil/.local/lib/python3.10/site-packages (from accelerate<0.22.0,>=0.21.0->autogluon.multimodal==1.1.0->autogluon) (6.0.1)
# Requirement already satisfied: botocore<1.35.0,>=1.34.113 in /home/sunil/.local/lib/python3.10/site-packages (from boto3<2,>=1.10->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (1.34.113)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/sunil/.local/lib/python3.10/site-packages (from boto3<2,>=1.10->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (0.10.0)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /home/sunil/.local/lib/python3.10/site-packages (from boto3<2,>=1.10->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (0.10.1)
# Requirement already satisfied: graphviz in /home/sunil/.local/lib/python3.10/site-packages (from catboost<1.3,>=1.1->autogluon.tabular[all]==1.1.0->autogluon) (0.8.4)
# Requirement already satisfied: plotly in /home/sunil/.local/lib/python3.10/site-packages (from catboost<1.3,>=1.1->autogluon.tabular[all]==1.1.0->autogluon) (5.22.0)
# Requirement already satisfied: datasets>=2.0.0 in /home/sunil/.local/lib/python3.10/site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (2.19.1)
# Requirement already satisfied: dill in /home/sunil/.local/lib/python3.10/site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (0.3.8)
# Requirement already satisfied: xxhash in /home/sunil/.local/lib/python3.10/site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (3.4.1)
# Requirement already satisfied: multiprocess in /home/sunil/.local/lib/python3.10/site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /home/sunil/.local/lib/python3.10/site-packages (from fsspec[http]>=2021.05.0->evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (2024.3.1)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /home/sunil/.local/lib/python3.10/site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (0.22.2)
# Requirement already satisfied: pip in /home/sunil/.local/lib/python3.10/site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (24.0)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /home/sunil/.local/lib/python3.10/site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (0.0.7)
# Requirement already satisfied: fastcore<1.6,>=1.5.29 in /home/sunil/.local/lib/python3.10/site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (1.5.38)
# Requirement already satisfied: fastprogress>=0.2.4 in /home/sunil/.local/lib/python3.10/site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (1.0.3)
# Requirement already satisfied: spacy<4 in /home/sunil/.local/lib/python3.10/site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (3.7.4)
# Requirement already satisfied: pydantic<3,>=1.7 in /home/sunil/.local/lib/python3.10/site-packages (from gluonts<0.14.4,>=0.14.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (2.7.1)
# Requirement already satisfied: toolz~=0.10 in /home/sunil/.local/lib/python3.10/site-packages (from gluonts<0.14.4,>=0.14.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.12.1)
# Requirement already satisfied: typing-extensions~=4.0 in /home/sunil/.local/lib/python3.10/site-packages (from gluonts<0.14.4,>=0.14.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (4.11.0)
# Requirement already satisfied: future in /home/sunil/.local/lib/python3.10/site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==1.1.0->autogluon) (1.0.0)
# Requirement already satisfied: cloudpickle in /home/sunil/.local/lib/python3.10/site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==1.1.0->autogluon) (3.0.0)
# Requirement already satisfied: py4j in /home/sunil/.local/lib/python3.10/site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==1.1.0->autogluon) (0.10.9.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sunil/.local/lib/python3.10/site-packages (from jinja2<3.2,>=3.0.3->autogluon.multimodal==1.1.0->autogluon) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /home/sunil/.local/lib/python3.10/site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.1.0->autogluon) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/sunil/.local/lib/python3.10/site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.1.0->autogluon) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/sunil/.local/lib/python3.10/site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.1.0->autogluon) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/sunil/.local/lib/python3.10/site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.1.0->autogluon) (0.18.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.8.0 in /home/sunil/.local/lib/python3.10/site-packages (from lightning<2.2,>=2.1->autogluon.multimodal==1.1.0->autogluon) (0.11.2)
# Requirement already satisfied: numba in /home/sunil/.local/lib/python3.10/site-packages (from mlforecast<0.10.1,>=0.10.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.59.1)
# Requirement already satisfied: window-ops in /home/sunil/.local/lib/python3.10/site-packages (from mlforecast<0.10.1,>=0.10.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.0.15)
# Requirement already satisfied: gdown>=4.0.0 in /home/sunil/.local/lib/python3.10/site-packages (from nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.1.0->autogluon) (5.2.0)
# Requirement already satisfied: click in /home/sunil/.local/lib/python3.10/site-packages (from nltk<4.0.0,>=3.4.5->autogluon.multimodal==1.1.0->autogluon) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in /home/sunil/.local/lib/python3.10/site-packages (from nltk<4.0.0,>=3.4.5->autogluon.multimodal==1.1.0->autogluon) (2024.4.16)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/sunil/.local/lib/python3.10/site-packages (from omegaconf<2.3.0,>=2.1.1->autogluon.multimodal==1.1.0->autogluon) (4.9.3)
# Requirement already satisfied: colorama in /usr/lib/python3/dist-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (0.4.4)
# Requirement already satisfied: model-index in /home/sunil/.local/lib/python3.10/site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (0.1.11)
# Requirement already satisfied: opendatalab in /home/sunil/.local/lib/python3.10/site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (0.0.10)
# Requirement already satisfied: rich in /home/sunil/.local/lib/python3.10/site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (13.4.2)
# Requirement already satisfied: tabulate in /home/sunil/.local/lib/python3.10/site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (0.9.0)
# Requirement already satisfied: coloredlogs in /home/sunil/.local/lib/python3.10/site-packages (from optimum<1.19,>=1.17->optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon) (15.0.1)
# Requirement already satisfied: sympy in /home/sunil/.local/lib/python3.10/site-packages (from optimum<1.19,>=1.17->optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon) (1.12)
# Requirement already satisfied: onnx in /home/sunil/.local/lib/python3.10/site-packages (from optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon) (1.16.1)
# Requirement already satisfied: onnxruntime>=1.11.0 in /home/sunil/.local/lib/python3.10/site-packages (from optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon) (1.18.0)
# Requirement already satisfied: protobuf>=3.20.1 in /home/sunil/.local/lib/python3.10/site-packages (from optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon) (4.25.3)
# Requirement already satisfied: filelock in /home/sunil/.local/lib/python3.10/site-packages (from ray<2.11,>=2.10.0->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (3.14.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /home/sunil/.local/lib/python3.10/site-packages (from ray<2.11,>=2.10.0->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (1.0.8)
# Requirement already satisfied: aiosignal in /home/sunil/.local/lib/python3.10/site-packages (from ray<2.11,>=2.10.0->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (1.3.1)
# Requirement already satisfied: frozenlist in /home/sunil/.local/lib/python3.10/site-packages (from ray<2.11,>=2.10.0->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (1.4.1)
# Requirement already satisfied: aiohttp>=3.7 in /home/sunil/.local/lib/python3.10/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (3.9.5)
# Requirement already satisfied: aiohttp-cors in /home/sunil/.local/lib/python3.10/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (0.7.0)
# Requirement already satisfied: colorful in /home/sunil/.local/lib/python3.10/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (0.5.6)
# Requirement already satisfied: py-spy>=0.2.0 in /home/sunil/.local/lib/python3.10/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (0.3.14)
# Requirement already satisfied: opencensus in /home/sunil/.local/lib/python3.10/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (0.11.4)
# Requirement already satisfied: prometheus-client>=0.7.1 in /home/sunil/.local/lib/python3.10/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (0.20.0)
# Requirement already satisfied: smart-open in /home/sunil/.local/lib/python3.10/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (6.4.0)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in /home/sunil/.local/lib/python3.10/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (20.26.2)
# Requirement already satisfied: grpcio>=1.42.0 in /home/sunil/.local/lib/python3.10/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (1.62.2)
# Requirement already satisfied: tensorboardX>=1.9 in /home/sunil/.local/lib/python3.10/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (2.6.2.2)
# Requirement already satisfied: pyarrow>=6.0.1 in /home/sunil/.local/lib/python3.10/site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (16.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sunil/.local/lib/python3.10/site-packages (from requests->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sunil/.local/lib/python3.10/site-packages (from requests->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (2024.7.4)
# Requirement already satisfied: imageio>=2.4.1 in /home/sunil/.local/lib/python3.10/site-packages (from scikit-image<0.21.0,>=0.19.1->autogluon.multimodal==1.1.0->autogluon) (2.34.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/sunil/.local/lib/python3.10/site-packages (from scikit-image<0.21.0,>=0.19.1->autogluon.multimodal==1.1.0->autogluon) (2024.5.22)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/sunil/.local/lib/python3.10/site-packages (from scikit-image<0.21.0,>=0.19.1->autogluon.multimodal==1.1.0->autogluon) (1.6.0)
# Requirement already satisfied: lazy_loader>=0.1 in /home/sunil/.local/lib/python3.10/site-packages (from scikit-image<0.21.0,>=0.19.1->autogluon.multimodal==1.1.0->autogluon) (0.4)
# Requirement already satisfied: statsmodels>=0.13.2 in /home/sunil/.local/lib/python3.10/site-packages (from statsforecast<1.5,>=1.4.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.14.2)
# Requirement already satisfied: absl-py>=0.4 in /home/sunil/.local/lib/python3.10/site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.1.0->autogluon) (2.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/sunil/.local/lib/python3.10/site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.1.0->autogluon) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/sunil/.local/lib/python3.10/site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.1.0->autogluon) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/sunil/.local/lib/python3.10/site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.1.0->autogluon) (3.0.2)
# Requirement already satisfied: safetensors in /home/sunil/.local/lib/python3.10/site-packages (from timm<0.10.0,>=0.9.5->autogluon.multimodal==1.1.0->autogluon) (0.4.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/sunil/.local/lib/python3.10/site-packages (from torch<2.2,>=2.1->autogluon.multimodal==1.1.0->autogluon) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/sunil/.local/lib/python3.10/site-packages (from torch<2.2,>=2.1->autogluon.multimodal==1.1.0->autogluon) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/sunil/.local/lib/python3.10/site-packages (from torch<2.2,>=2.1->autogluon.multimodal==1.1.0->autogluon) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/sunil/.local/lib/python3.10/site-packages (from torch<2.2,>=2.1->autogluon.multimodal==1.1.0->autogluon) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/sunil/.local/lib/python3.10/site-packages (from torch<2.2,>=2.1->autogluon.multimodal==1.1.0->autogluon) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/sunil/.local/lib/python3.10/site-packages (from torch<2.2,>=2.1->autogluon.multimodal==1.1.0->autogluon) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/sunil/.local/lib/python3.10/site-packages (from torch<2.2,>=2.1->autogluon.multimodal==1.1.0->autogluon) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/sunil/.local/lib/python3.10/site-packages (from torch<2.2,>=2.1->autogluon.multimodal==1.1.0->autogluon) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/sunil/.local/lib/python3.10/site-packages (from torch<2.2,>=2.1->autogluon.multimodal==1.1.0->autogluon) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/sunil/.local/lib/python3.10/site-packages (from torch<2.2,>=2.1->autogluon.multimodal==1.1.0->autogluon) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/sunil/.local/lib/python3.10/site-packages (from torch<2.2,>=2.1->autogluon.multimodal==1.1.0->autogluon) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /home/sunil/.local/lib/python3.10/site-packages (from torch<2.2,>=2.1->autogluon.multimodal==1.1.0->autogluon) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/sunil/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<2.2,>=2.1->autogluon.multimodal==1.1.0->autogluon) (12.4.127)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/sunil/.local/lib/python3.10/site-packages (from transformers<4.39.0,>=4.38.0->transformers[sentencepiece]<4.39.0,>=4.38.0->autogluon.multimodal==1.1.0->autogluon) (0.15.2)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /home/sunil/.local/lib/python3.10/site-packages (from transformers[sentencepiece]<4.39.0,>=4.38.0->autogluon.multimodal==1.1.0->autogluon) (0.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sunil/.local/lib/python3.10/site-packages (from matplotlib->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/sunil/.local/lib/python3.10/site-packages (from matplotlib->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sunil/.local/lib/python3.10/site-packages (from matplotlib->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/sunil/.local/lib/python3.10/site-packages (from matplotlib->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (2.4.7)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/sunil/.local/lib/python3.10/site-packages (from aiohttp>=3.7->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/sunil/.local/lib/python3.10/site-packages (from aiohttp>=3.7->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/sunil/.local/lib/python3.10/site-packages (from aiohttp>=3.7->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (4.0.3)
# Requirement already satisfied: pyarrow-hotfix in /home/sunil/.local/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (0.6)
# Requirement already satisfied: beautifulsoup4 in /home/sunil/.local/lib/python3.10/site-packages (from gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.1.0->autogluon) (4.12.3)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /home/sunil/.local/lib/python3.10/site-packages (from numba->mlforecast<0.10.1,>=0.10.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.42.0)
# Requirement already satisfied: flatbuffers in /home/sunil/.local/lib/python3.10/site-packages (from onnxruntime>=1.11.0->optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon) (24.3.25)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/sunil/.local/lib/python3.10/site-packages (from pydantic<3,>=1.7->gluonts<0.14.4,>=0.14.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /home/sunil/.local/lib/python3.10/site-packages (from pydantic<3,>=1.7->gluonts<0.14.4,>=0.14.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (2.18.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/sunil/.local/lib/python3.10/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/sunil/.local/lib/python3.10/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/sunil/.local/lib/python3.10/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/sunil/.local/lib/python3.10/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/sunil/.local/lib/python3.10/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /home/sunil/.local/lib/python3.10/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/sunil/.local/lib/python3.10/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/sunil/.local/lib/python3.10/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/sunil/.local/lib/python3.10/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /home/sunil/.local/lib/python3.10/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/sunil/.local/lib/python3.10/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (0.9.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/sunil/.local/lib/python3.10/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (3.4.0)
# Requirement already satisfied: patsy>=0.5.6 in /home/sunil/.local/lib/python3.10/site-packages (from statsmodels>=0.13.2->statsforecast<1.5,>=1.4.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.5.6)
# Requirement already satisfied: distlib<1,>=0.3.7 in /home/sunil/.local/lib/python3.10/site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (0.3.8)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /home/sunil/.local/lib/python3.10/site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (4.2.0)
# Requirement already satisfied: humanfriendly>=9.1 in /home/sunil/.local/lib/python3.10/site-packages (from coloredlogs->optimum<1.19,>=1.17->optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon) (10.0)
# Requirement already satisfied: ordered-set in /home/sunil/.local/lib/python3.10/site-packages (from model-index->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (4.1.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in /home/sunil/.local/lib/python3.10/site-packages (from opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /home/sunil/.local/lib/python3.10/site-packages (from opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (2.19.0)
# Requirement already satisfied: pycryptodome in /home/sunil/.local/lib/python3.10/site-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (3.20.0)
# Requirement already satisfied: openxlab in /home/sunil/.local/lib/python3.10/site-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (0.1.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/sunil/.local/lib/python3.10/site-packages (from plotly->catboost<1.3,>=1.1->autogluon.tabular[all]==1.1.0->autogluon) (8.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/sunil/.local/lib/python3.10/site-packages (from rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (2.15.1)
# Requirement already satisfied: mpmath>=0.19 in /home/sunil/.local/lib/python3.10/site-packages (from sympy->optimum<1.19,>=1.17->optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon) (1.3.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /home/sunil/.local/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (1.63.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /home/sunil/.local/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (1.23.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /home/sunil/.local/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (2.29.0)
# Requirement already satisfied: language-data>=1.2 in /home/sunil/.local/lib/python3.10/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (1.2.0)
# Requirement already satisfied: mdurl~=0.1 in /home/sunil/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (0.1.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/sunil/.local/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/sunil/.local/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (0.1.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /home/sunil/.local/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (0.16.0)
# Requirement already satisfied: soupsieve>1.2 in /home/sunil/.local/lib/python3.10/site-packages (from beautifulsoup4->gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.1.0->autogluon) (2.5)
# Requirement already satisfied: oss2~=2.17.0 in /home/sunil/.local/lib/python3.10/site-packages (from openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (2.17.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/sunil/.local/lib/python3.10/site-packages (from requests[socks]->gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.1.0->autogluon) (1.7.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/sunil/.local/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/lib/python3/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (0.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/sunil/.local/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (4.9)
# Requirement already satisfied: marisa-trie>=0.7.7 in /home/sunil/.local/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (1.1.1)
# Requirement already satisfied: aliyun-python-sdk-core>=2.13.12 in /home/sunil/.local/lib/python3.10/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (2.15.1)
# Requirement already satisfied: aliyun-python-sdk-kms>=2.4.1 in /home/sunil/.local/lib/python3.10/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (2.16.3)
# Requirement already satisfied: crcmod>=1.7 in /home/sunil/.local/lib/python3.10/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (1.7)
# Requirement already satisfied: cryptography>=2.6.0 in /usr/lib/python3/dist-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (3.4.8)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/lib/python3/dist-packages (from rsa<5,>=3.1.4->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (0.4.8)
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
df = pd.read_csv("/home/sunil/am2/MLinMS/Hacathon_ML_model/spiderdatasets_hacathon.csv")

# %%
df
# Out:
#     Mass_Dust_Particle_in_gram  Mass_of_Fixed_Thread_Particle   \
# 0                         1.64                         1000000
# 1                         1.64                         1000000
# 2                         1.64                         1000000
# 3                         1.64                         1000000
# 4                         1.64                         1000000
# ..                         ...                             ...
# 75                       19.70                         1000000
# 76                       19.70                         1000000
# 77                       19.70                         1000000
# 78                       19.70                         1000000
# 79                       19.70                         1000000
#
#     Mass_of_Thread_particle_(_milliGram)  Velocity_in__(m/sec)      Timestep  \
# 0                                   0.27                   0.1  1.600000e-08
# 1                                   0.27                   0.1  8.000000e-09
# 2                                   0.27                   0.3  8.000000e-09
# 3                                   0.27                   0.3  8.000000e-09
# 4                                   0.27                   0.5  8.000000e-09
# ..                                   ...                   ...           ...
# 75                                  0.27                   0.5  8.000000e-09
# 76                                  0.27                   0.7  8.000000e-09
# 77                                  0.27                   0.7  8.000000e-09
# 78                                  0.27                   1.0  8.000000e-09
# 79                                  0.27                   1.0  8.000000e-09
#
#     Radius_of_Dust__Sphere_(mm)         Rupture_Results
# 0                             1  No Ruptures & Rebounds
# 1                             2  No Ruptures & Rebounds
# 2                             1  No Ruptures & Rebounds
# 3                             2  No Ruptures & Rebounds
# 4                             1  No Ruptures & Rebounds
# ..                          ...                     ...
# 75                            2  No Ruptures & Rebounds
# 76                            1  No Ruptures & Rebounds
# 77                            2  No Ruptures & Rebounds
# 78                            1  No Ruptures & Rebounds
# 79                            2  No Ruptures & Rebounds
#
# [80 rows x 7 columns]

# %%
from autogluon.tabular import TabularDataset, TabularPredictor
data = TabularDataset(df)
data
# Out:
#     Mass_Dust_Particle_in_gram  Mass_of_Fixed_Thread_Particle   \
# 0                         1.64                         1000000
# 1                         1.64                         1000000
# 2                         1.64                         1000000
# 3                         1.64                         1000000
# 4                         1.64                         1000000
# ..                         ...                             ...
# 75                       19.70                         1000000
# 76                       19.70                         1000000
# 77                       19.70                         1000000
# 78                       19.70                         1000000
# 79                       19.70                         1000000
#
#     Mass_of_Thread_particle_(_milliGram)  Velocity_in__(m/sec)      Timestep  \
# 0                                   0.27                   0.1  1.600000e-08
# 1                                   0.27                   0.1  8.000000e-09
# 2                                   0.27                   0.3  8.000000e-09
# 3                                   0.27                   0.3  8.000000e-09
# 4                                   0.27                   0.5  8.000000e-09
# ..                                   ...                   ...           ...
# 75                                  0.27                   0.5  8.000000e-09
# 76                                  0.27                   0.7  8.000000e-09
# 77                                  0.27                   0.7  8.000000e-09
# 78                                  0.27                   1.0  8.000000e-09
# 79                                  0.27                   1.0  8.000000e-09
#
#     Radius_of_Dust__Sphere_(mm)         Rupture_Results
# 0                             1  No Ruptures & Rebounds
# 1                             2  No Ruptures & Rebounds
# 2                             1  No Ruptures & Rebounds
# 3                             2  No Ruptures & Rebounds
# 4                             1  No Ruptures & Rebounds
# ..                          ...                     ...
# 75                            2  No Ruptures & Rebounds
# 76                            1  No Ruptures & Rebounds
# 77                            2  No Ruptures & Rebounds
# 78                            1  No Ruptures & Rebounds
# 79                            2  No Ruptures & Rebounds
#
# [80 rows x 7 columns]

# %%
data['Rupture_Results'] = data['Rupture_Results'].str.strip()

# %%
data
# Out:
#     Mass_Dust_Particle_in_gram  Mass_of_Fixed_Thread_Particle   \
# 0                         1.64                         1000000
# 1                         1.64                         1000000
# 2                         1.64                         1000000
# 3                         1.64                         1000000
# 4                         1.64                         1000000
# ..                         ...                             ...
# 75                       19.70                         1000000
# 76                       19.70                         1000000
# 77                       19.70                         1000000
# 78                       19.70                         1000000
# 79                       19.70                         1000000
#
#     Mass_of_Thread_particle_(_milliGram)  Velocity_in__(m/sec)      Timestep  \
# 0                                   0.27                   0.1  1.600000e-08
# 1                                   0.27                   0.1  8.000000e-09
# 2                                   0.27                   0.3  8.000000e-09
# 3                                   0.27                   0.3  8.000000e-09
# 4                                   0.27                   0.5  8.000000e-09
# ..                                   ...                   ...           ...
# 75                                  0.27                   0.5  8.000000e-09
# 76                                  0.27                   0.7  8.000000e-09
# 77                                  0.27                   0.7  8.000000e-09
# 78                                  0.27                   1.0  8.000000e-09
# 79                                  0.27                   1.0  8.000000e-09
#
#     Radius_of_Dust__Sphere_(mm)         Rupture_Results
# 0                             1  No Ruptures & Rebounds
# 1                             2  No Ruptures & Rebounds
# 2                             1  No Ruptures & Rebounds
# 3                             2  No Ruptures & Rebounds
# 4                             1  No Ruptures & Rebounds
# ..                          ...                     ...
# 75                            2  No Ruptures & Rebounds
# 76                            1  No Ruptures & Rebounds
# 77                            2  No Ruptures & Rebounds
# 78                            1  No Ruptures & Rebounds
# 79                            2  No Ruptures & Rebounds
#
# [80 rows x 7 columns]

# %%
# Split the data into train and test datasets
from sklearn.model_selection import train_test_split

D_train, D_test = train_test_split(data, test_size=0.20, random_state=42)

# %%
D_train
# Out:
#     Mass_Dust_Particle_in_gram  Mass_of_Fixed_Thread_Particle   \
# 73                       19.70                         1000000
# 61                       16.42                         1000000
# 55                       13.14                         1000000
# 40                        9.85                         1000000
# 9                         1.64                         1000000
# ..                         ...                             ...
# 20                        4.96                         1000000
# 60                       16.42                         1000000
# 71                       19.70                         1000000
# 14                        3.28                         1000000
# 51                       13.14                         1000000
#
#     Mass_of_Thread_particle_(_milliGram)  Velocity_in__(m/sec)      Timestep  \
# 73                                  0.27                   0.3  8.000000e-09
# 61                                  0.27                   0.1  8.000000e-09
# 55                                  0.27                   0.5  8.000000e-09
# 40                                  0.27                   0.1  8.000000e-09
# 9                                   0.27                   1.0  8.000000e-09
# ..                                   ...                   ...           ...
# 20                                  0.27                   0.1  8.000000e-09
# 60                                  0.27                   0.1  8.000000e-09
# 71                                  0.27                   0.1  8.000000e-09
# 14                                  0.27                   0.5  8.000000e-09
# 51                                  0.27                   0.1  8.000000e-09
#
#     Radius_of_Dust__Sphere_(mm)         Rupture_Results
# 73                            2  No Ruptures & Rebounds
# 61                            2  No Ruptures & Rebounds
# 55                            2                Ruptures
# 40                            1  No Ruptures & Rebounds
# 9                             2                Ruptures
# ..                          ...                     ...
# 20                            1  No Ruptures & Rebounds
# 60                            1  No Ruptures & Rebounds
# 71                            2                Ruptures
# 14                            1                Ruptures
# 51                            2  No Ruptures & Rebounds
#
# [64 rows x 7 columns]

# %%
label = 'Rupture_Results'
D_train[label].describe()
# Out:
# count                         64
# unique                         2
# top       No Ruptures & Rebounds
# freq                          49
# Name: Rupture_Results, dtype: object

# %%
D_test
# Out:
#     Mass_Dust_Particle_in_gram  Mass_of_Fixed_Thread_Particle   \
# 30                        6.57                         1000000
# 0                         1.64                         1000000
# 22                        4.96                         1000000
# 31                        6.57                         1000000
# 18                        3.28                         1000000
# 28                        4.96                         1000000
# 10                        3.28                         1000000
# 70                       19.70                         1000000
# 4                         1.64                         1000000
# 12                        3.28                         1000000
# 49                        9.85                         1000000
# 33                        6.57                         1000000
# 67                       16.42                         1000000
# 35                        6.57                         1000000
# 68                       16.42                         1000000
# 45                        9.85                         1000000
#
#     Mass_of_Thread_particle_(_milliGram)  Velocity_in__(m/sec)      Timestep  \
# 30                                  0.27                   0.1  8.000000e-09
# 0                                   0.27                   0.1  1.600000e-08
# 22                                  0.27                   0.3  8.000000e-09
# 31                                  0.27                   0.1  8.000000e-09
# 18                                  0.27                   1.0  8.000000e-09
# 28                                  0.27                   1.0  8.000000e-09
# 10                                  0.27                   0.1  8.000000e-09
# 70                                  0.27                   0.1  8.000000e-09
# 4                                   0.27                   0.5  8.000000e-09
# 12                                  0.27                   0.3  8.000000e-09
# 49                                  0.27                   1.0  8.000000e-09
# 33                                  0.27                   0.3  8.000000e-09
# 67                                  0.27                   0.7  8.000000e-09
# 35                                  0.27                   0.5  8.000000e-09
# 68                                  0.27                   1.0  8.000000e-09
# 45                                  0.27                   0.5  8.000000e-09
#
#     Radius_of_Dust__Sphere_(mm)         Rupture_Results
# 30                            1  No Ruptures & Rebounds
# 0                             1  No Ruptures & Rebounds
# 22                            1  No Ruptures & Rebounds
# 31                            2  No Ruptures & Rebounds
# 18                            1                Ruptures
# 28                            1  No Ruptures & Rebounds
# 10                            1  No Ruptures & Rebounds
# 70                            1                Ruptures
# 4                             1  No Ruptures & Rebounds
# 12                            1  No Ruptures & Rebounds
# 49                            2  No Ruptures & Rebounds
# 33                            2                Ruptures
# 67                            2  No Ruptures & Rebounds
# 35                            2  No Ruptures & Rebounds
# 68                            1  No Ruptures & Rebounds
# 45                            2  No Ruptures & Rebounds

# %%
label = 'Rupture_Results'
D_test[label].describe()
# Out:
# count                         16
# unique                         2
# top       No Ruptures & Rebounds
# freq                          13
# Name: Rupture_Results, dtype: object

# %%
data.columns
# Out:
# Index(['Mass_Dust_Particle_in_gram', 'Mass_of_Fixed_Thread_Particle ',
#        'Mass_of_Thread_particle_(_milliGram)', 'Velocity_in__(m/sec)',
#        'Timestep', 'Radius_of_Dust__Sphere_(mm)', 'Rupture_Results'],
#       dtype='object')

# %%
predictor = TabularPredictor(
    label="Rupture_Results",
    problem_type="binary",
).fit(D_train, time_limit=60, presets="best_quality")
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20240729_084336"
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=6, num_bag_sets=1
# Dynamic stacking is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# Detecting stacked overfitting by sub-fitting AutoGluon on the input data. That is, copies of AutoGluon will be sub-fit on subset(s) of the data. Then, the holdout validation data is used to detect stacked overfitting.
# Sub-fit(s) time limit is: 60 seconds.
# Starting holdout-based sub-fit for dynamic stacking. Context path is: AutogluonModels/ag-20240729_084336/ds_sub_fit/sub_fit_ho.
# Running the sub-fit in a ray process to avoid memory leakage.
# Spend 23 seconds for the sub-fit(s) during dynamic stacking.
# Time left for full fit of AutoGluon: 37 seconds.
# Starting full fit now with num_stack_levels 1.
# Beginning AutoGluon training ... Time limit = 37s
# AutoGluon will save models to "AutogluonModels/ag-20240729_084336"
# =================== System Info ===================
# AutoGluon Version:  1.1.0
# Python Version:     3.10.12
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #123-Ubuntu SMP Mon Jun 10 08:16:17 UTC 2024
# CPU Count:          192
# Memory Avail:       440.46 GB / 1007.45 GB (43.7%)
# Disk Space Avail:   3551.41 GB / 7096.34 GB (50.0%)
# ===================================================
# Train Data Rows:    64
# Train Data Columns: 6
# Label Column:       Rupture_Results
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = Ruptures, class 0 = No Ruptures & Rebounds
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (Ruptures) vs negative (No Ruptures & Rebounds) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    451036.92 MB
# 	Train Data (Original)  Memory Usage: 0.00 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Useless Original Features (Count: 3): ['Mass_of_Fixed_Thread_Particle ', 'Mass_of_Thread_particle_(_milliGram)', 'Timestep']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 2 | ['Mass_Dust_Particle_in_gram', 'Velocity_in__(m/sec)']
# 		('int', [])   : 1 | ['Radius_of_Dust__Sphere_(mm)']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 2 | ['Mass_Dust_Particle_in_gram', 'Velocity_in__(m/sec)']
# 		('int', ['bool']) : 1 | ['Radius_of_Dust__Sphere_(mm)']
# 	0.0s = Fit runtime
# 	3 features in original data used to generate 3 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.00 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.06s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 24.62s of the 36.94s of remaining time.
# 	0.7969	 = Validation score   (accuracy)
# 	0.0s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 24.56s of the 36.87s of remaining time.
# 	0.9531	 = Validation score   (accuracy)
# 	0.0s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 24.52s of the 36.83s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (6 workers, per: cpus=32, gpus=0, memory=0.00%)
# 	0.7812	 = Validation score   (accuracy)
# 	0.28s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 22.94s of the 35.25s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (6 workers, per: cpus=32, gpus=0, memory=0.00%)
# 	0.7812	 = Validation score   (accuracy)
# 	0.59s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 21.34s of the 33.66s of remaining time.
# 	0.7188	 = Validation score   (accuracy)
# 	0.53s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 20.71s of the 33.02s of remaining time.
# 	0.7188	 = Validation score   (accuracy)
# 	0.37s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 20.19s of the 32.5s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (6 workers, per: cpus=32, gpus=0, memory=0.00%)
# 	0.875	 = Validation score   (accuracy)
# 	1.03s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 18.16s of the 30.47s of remaining time.
# 	0.75	 = Validation score   (accuracy)
# 	0.34s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 17.71s of the 30.02s of remaining time.
# 	0.7344	 = Validation score   (accuracy)
# 	0.39s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 17.16s of the 29.47s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (6 workers, per: cpus=32, gpus=0, memory=0.00%)
# 	0.8438	 = Validation score   (accuracy)
# 	2.99s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 13.18s of the 25.49s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (6 workers, per: cpus=32, gpus=0, memory=0.00%)
# 	0.8281	 = Validation score   (accuracy)
# 	1.01s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 10.85s of the 23.16s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (6 workers, per: cpus=32, gpus=0, memory=0.00%)
# 	0.7656	 = Validation score   (accuracy)
# 	2.75s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 6.78s of the 19.09s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (6 workers, per: cpus=32, gpus=0, memory=0.00%)
# 	0.8125	 = Validation score   (accuracy)
# 	0.4s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 5.06s of the 17.37s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (6 workers, per: cpus=32, gpus=0, memory=0.00%)
# 	0.8594	 = Validation score   (accuracy)
# 	0.72s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 2.98s of the 15.29s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (6 workers, per: cpus=32, gpus=0, memory=0.00%)
# 	Time limit exceeded... Skipping NeuralNetTorch_r79_BAG_L1.
# 2024-07-29 10:44:25,980	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-07-29 10:44:25,981	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-07-29 10:44:25,990	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 36.94s of the 11.49s of remaining time.
# 2024-07-29 10:44:25,994	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-07-29 10:44:25,994	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	Ensemble Weights: {'KNeighborsDist_BAG_L1': 1.0}
# 	0.9531	 = Validation score   (accuracy)
# 	0.1s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 11.34s of the 11.31s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (6 workers, per: cpus=32, gpus=0, memory=0.00%)
# 	0.8594	 = Validation score   (accuracy)
# 	0.28s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 9.77s of the 9.74s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (6 workers, per: cpus=32, gpus=0, memory=0.00%)
# 	0.8594	 = Validation score   (accuracy)
# 	0.56s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 8.21s of the 8.18s of remaining time.
# 	0.9375	 = Validation score   (accuracy)
# 	0.4s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 7.69s of the 7.66s of remaining time.
# 	0.9375	 = Validation score   (accuracy)
# 	0.38s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 7.16s of the 7.13s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (6 workers, per: cpus=32, gpus=0, memory=0.00%)
# 	0.9531	 = Validation score   (accuracy)
# 	1.13s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 5.08s of the 5.05s of remaining time.
# 	0.9531	 = Validation score   (accuracy)
# 	0.38s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 4.59s of the 4.56s of remaining time.
# 	0.9531	 = Validation score   (accuracy)
# 	0.5s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 3.97s of the 3.93s of remaining time.
# 	Fitting 6 child models (S1F1 - S1F6) | Fitting with ParallelLocalFoldFittingStrategy (6 workers, per: cpus=32, gpus=0, memory=0.00%)
# 	0.9375	 = Validation score   (accuracy)
# 	2.7s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 36.94s of the -0.33s of remaining time.
# 	Ensemble Weights: {'KNeighborsDist_BAG_L1': 1.0}
# 	0.9531	 = Validation score   (accuracy)
# 	0.15s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 37.53s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20240729_084336")

# %%
test_data = TabularDataset(D_test)

# %%
test_data
# Out:
#     Mass_Dust_Particle_in_gram  Mass_of_Fixed_Thread_Particle   \
# 30                        6.57                         1000000
# 0                         1.64                         1000000
# 22                        4.96                         1000000
# 31                        6.57                         1000000
# 18                        3.28                         1000000
# 28                        4.96                         1000000
# 10                        3.28                         1000000
# 70                       19.70                         1000000
# 4                         1.64                         1000000
# 12                        3.28                         1000000
# 49                        9.85                         1000000
# 33                        6.57                         1000000
# 67                       16.42                         1000000
# 35                        6.57                         1000000
# 68                       16.42                         1000000
# 45                        9.85                         1000000
#
#     Mass_of_Thread_particle_(_milliGram)  Velocity_in__(m/sec)      Timestep  \
# 30                                  0.27                   0.1  8.000000e-09
# 0                                   0.27                   0.1  1.600000e-08
# 22                                  0.27                   0.3  8.000000e-09
# 31                                  0.27                   0.1  8.000000e-09
# 18                                  0.27                   1.0  8.000000e-09
# 28                                  0.27                   1.0  8.000000e-09
# 10                                  0.27                   0.1  8.000000e-09
# 70                                  0.27                   0.1  8.000000e-09
# 4                                   0.27                   0.5  8.000000e-09
# 12                                  0.27                   0.3  8.000000e-09
# 49                                  0.27                   1.0  8.000000e-09
# 33                                  0.27                   0.3  8.000000e-09
# 67                                  0.27                   0.7  8.000000e-09
# 35                                  0.27                   0.5  8.000000e-09
# 68                                  0.27                   1.0  8.000000e-09
# 45                                  0.27                   0.5  8.000000e-09
#
#     Radius_of_Dust__Sphere_(mm)         Rupture_Results
# 30                            1  No Ruptures & Rebounds
# 0                             1  No Ruptures & Rebounds
# 22                            1  No Ruptures & Rebounds
# 31                            2  No Ruptures & Rebounds
# 18                            1                Ruptures
# 28                            1  No Ruptures & Rebounds
# 10                            1  No Ruptures & Rebounds
# 70                            1                Ruptures
# 4                             1  No Ruptures & Rebounds
# 12                            1  No Ruptures & Rebounds
# 49                            2  No Ruptures & Rebounds
# 33                            2                Ruptures
# 67                            2  No Ruptures & Rebounds
# 35                            2  No Ruptures & Rebounds
# 68                            1  No Ruptures & Rebounds
# 45                            2  No Ruptures & Rebounds

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix

# Assuming you have a DataFrame 'test_data' and a model 'predictor'
label = 'Rupture_Results'  # Column name for actual outcomes

# Predicting outcomes
y_pred = predictor.predict(test_data.drop(columns=[label]))

# Assuming the actual labels are in test_data under the column 'Rupture_Results'
y_true = test_data[label]

# Define the positive class label
positive_class_label = 'No Ruptures & Rebounds'

# Calculate evaluation metrics
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, pos_label=positive_class_label)
recall = recall_score(y_true, y_pred, pos_label=positive_class_label)
f1 = f1_score(y_true, y_pred, pos_label=positive_class_label)
conf_matrix = confusion_matrix(y_true, y_pred)


print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Confusion Matrix:\n", conf_matrix)
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Confusion Matrix:
#  [[13  0]
#  [ 0  3]]

# %%
import matplotlib.pyplot as plt
# Bar plot for Accuracy, Precision, Recall, and F1 Score
plt.subplot(2, 2, 1)
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score']
values = [accuracy, precision, recall, f1]
plt.bar(metrics, values)
plt.title('Model Performance Metrics')
plt.ylim(0, 1)
for i, v in enumerate(values):
    plt.text(i, v + 0.01, f'{v:.2f}', ha='center')

# %%
label="Rupture_Results"
y_pred = predictor.predict(test_data.drop(columns=[label]))

y_pred.head()
# Out:
# 30    No Ruptures & Rebounds
# 0     No Ruptures & Rebounds
# 22    No Ruptures & Rebounds
# 31    No Ruptures & Rebounds
# 18                  Ruptures
# Name: Rupture_Results, dtype: object

# %%
# Converting predictions to a numpy array
y_pred_array = y_pred.to_numpy()
y_pred_array
# Out:
# array(['No Ruptures & Rebounds', 'No Ruptures & Rebounds',
#        'No Ruptures & Rebounds', 'No Ruptures & Rebounds', 'Ruptures',
#        'No Ruptures & Rebounds', 'No Ruptures & Rebounds', 'Ruptures',
#        'No Ruptures & Rebounds', 'No Ruptures & Rebounds',
#        'No Ruptures & Rebounds', 'Ruptures', 'No Ruptures & Rebounds',
#        'No Ruptures & Rebounds', 'No Ruptures & Rebounds',
#        'No Ruptures & Rebounds'], dtype=object)

# %%
predictor.evaluate(test_data, silent=True)
# Out:
# {'accuracy': 1.0,
#  'balanced_accuracy': 1.0,
#  'mcc': 1.0,
#  'roc_auc': 1.0,
#  'f1': 1.0,
#  'precision': 1.0,
#  'recall': 1.0}

# %%
predictor.leaderboard(test_data)
# Out:
#                       model  score_test  score_val eval_metric  \
# 0     KNeighborsDist_BAG_L1      1.0000   0.953125    accuracy
# 1       WeightedEnsemble_L3      1.0000   0.953125    accuracy
# 2       WeightedEnsemble_L2      1.0000   0.953125    accuracy
# 3           CatBoost_BAG_L2      1.0000   0.953125    accuracy
# 4    NeuralNetFastAI_BAG_L2      1.0000   0.937500    accuracy
# 5     ExtraTreesGini_BAG_L2      1.0000   0.953125    accuracy
# 6   RandomForestEntr_BAG_L2      1.0000   0.937500    accuracy
# 7     ExtraTreesEntr_BAG_L2      1.0000   0.953125    accuracy
# 8   RandomForestGini_BAG_L2      1.0000   0.937500    accuracy
# 9     KNeighborsUnif_BAG_L1      0.8750   0.796875    accuracy
# 10     CatBoost_r177_BAG_L1      0.8125   0.859375    accuracy
# 11    NeuralNetTorch_BAG_L1      0.8125   0.765625    accuracy
# 12     LightGBMLarge_BAG_L1      0.8125   0.812500    accuracy
# 13          LightGBM_BAG_L1      0.8125   0.781250    accuracy
# 14        LightGBMXT_BAG_L1      0.8125   0.781250    accuracy
# 15           XGBoost_BAG_L1      0.8125   0.828125    accuracy
# 16        LightGBMXT_BAG_L2      0.8125   0.859375    accuracy
# 17          LightGBM_BAG_L2      0.8125   0.859375    accuracy
# 18          CatBoost_BAG_L1      0.7500   0.875000    accuracy
# 19   NeuralNetFastAI_BAG_L1      0.7500   0.843750    accuracy
# 20  RandomForestEntr_BAG_L1      0.6250   0.718750    accuracy
# 21  RandomForestGini_BAG_L1      0.6250   0.718750    accuracy
# 22    ExtraTreesEntr_BAG_L1      0.5625   0.734375    accuracy
# 23    ExtraTreesGini_BAG_L1      0.5000   0.750000    accuracy
#
#     pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 0         0.018726       0.016200   0.001923                 0.018726
# 1         0.019710       0.016679   0.148898                 0.000984
# 2         0.021685       0.016749   0.099502                 0.002959
# 3         3.430099       0.536728  12.520610                 0.010484
# 4         3.474170       0.560179  14.098357                 0.054555
# 5         3.483913       0.598738  11.778150                 0.064298
# 6         3.485676       0.625866  11.775555                 0.066061
# 7         3.486129       0.617597  11.891330                 0.066514
# 8         3.488273       0.590341  11.795300                 0.068658
# 9         0.023020       0.020177   0.002931                 0.023020
# 10        0.017907       0.021573   0.717033                 0.017907
# 11        0.033533       0.029019   2.751353                 0.033533
# 12        0.128136       0.003407   0.403112                 0.128136
# 13        0.145585       0.002771   0.588829                 0.145585
# 14        0.239585       0.003014   0.278044                 0.239585
# 15        0.259580       0.031124   1.006949                 0.259580
# 16        3.559284       0.529398  11.671723                 0.139669
# 17        3.563630       0.529988  11.957999                 0.144015
# 18        0.055323       0.030965   1.031076                 0.055323
# 19        2.146945       0.032313   2.986737                 2.146945
# 20        0.061639       0.099782   0.370570                 0.061639
# 21        0.170998       0.062860   0.532277                 0.170998
# 22        0.057632       0.106762   0.388364                 0.057632
# 23        0.061007       0.066392   0.335088                 0.061007
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.016200           0.001923            1       True
# 1                 0.000479           0.146975            3       True
# 2                 0.000548           0.097579            2       True
# 3                 0.010370           1.126324            2       True
# 4                 0.033821           2.704072            2       True
# 5                 0.072380           0.383864            2       True
# 6                 0.099508           0.381270            2       True
# 7                 0.091239           0.497044            2       True
# 8                 0.063983           0.401014            2       True
# 9                 0.020177           0.002931            1       True
# 10                0.021573           0.717033            1       True
# 11                0.029019           2.751353            1       True
# 12                0.003407           0.403112            1       True
# 13                0.002771           0.588829            1       True
# 14                0.003014           0.278044            1       True
# 15                0.031124           1.006949            1       True
# 16                0.003040           0.277437            2       True
# 17                0.003630           0.563714            2       True
# 18                0.030965           1.031076            1       True
# 19                0.032313           2.986737            1       True
# 20                0.099782           0.370570            1       True
# 21                0.062860           0.532277            1       True
# 22                0.106762           0.388364            1       True
# 23                0.066392           0.335088            1       True
#
#     fit_order
# 0           2
# 1          24
# 2          15
# 3          20
# 4          23
# 5          21
# 6          19
# 7          22
# 8          18
# 9           1
# 10         14
# 11         12
# 12         13
# 13          4
# 14          3
# 15         11
# 16         16
# 17         17
# 18          7
# 19         10
# 20          6
# 21          5
# 22          9
# 23          8

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt


predictions = predictor.predict(D_test.drop(columns=['Rupture_Results']))

actual = D_test['Rupture_Results']

cm = confusion_matrix(actual, predictions)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=predictor.classes_)
disp.plot(cmap=plt.cm.Blues, values_format='g')
plt.show()
